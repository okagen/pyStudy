# %%
# 統計用メソッドの勉強

# 株価データ取得モジュール 
import pandas_datareader.data as pdr

start = "1949/5/6"
end = "2016/9/30"

# pandas_datareaderを使って、yahooからNIKKEI225のデータを読み込み <DataFrame>
n225 = pdr.DataReader("^N225", 'yahoo', start, end)
print('\n--- n225.Close.head(10) <Series> ---')
print(n225.Close.head(5))

# 変化率
print('\n--- n225.Close.pct_change() <Series> ---')
print(n225.Close.pct_change().head(5))

# 差分
print('\n--- n225.Close.diff() <Series> ---')
print(n225.Close.diff().head(5))

# 計数
print('\n--- price.Close.count() <Value> ---')
print(n225.Close.count())

# 第１　四分位
print('\n--- price.Close.quantile(.25) <Value> ---')
print(n225.Close.quantile(.25))

# 第2　四分位
print('\n--- n225.Close.quantile(.5) <Value> ---')
print(n225.Close.quantile(.5))

# 第3　四分位
print('\n--- n225.Close.quantile(.75) <Value> ---')
print(n225.Close.quantile(.75))

# 合計
print('\n--- n225.Close.sum() <Value> ---')
print(n225.Close.sum())

# 累積合計
print('\n--- n225.Close.cumsum() <Series> ---')
print(n225.Close.cumsum().head(5))

# 平均
print('\n--- n225.Close.mean() <Value> ---')
print(n225.Close.mean())

# 中央値
print('\n--- n225.Close.median() <Value> ---')
print(n225.Close.median())

# 分散(variance)
print('\n--- n225.Close.var() <Value> ---')
print(n225.Close.var())

# 標準偏差(standard deviation)
print('\n--- n225.Close.std() <Value> ---')
print(n225.Close.std())

# 歪度(skewness)
print('\n--- n225.Close.skew() <Value> ---')
print(n225.Close.skew())

# 尖度(kurtosis)
print('\n--- n225.Close.kurt() <Value> ---')
print(n225.Close.kurt())
# Out:
# --- n225.Close.head(10) <Series> ---
# Date
# 1984-01-04     9927.0
# 1984-01-05     9947.0
# 1984-01-06     9961.0
# 1984-01-09     9954.0
# 1984-01-10    10016.0
# Name: Close, dtype: float64
#
# --- n225.Close.pct_change() <Series> ---
# Date
# 1984-01-04         NaN
# 1984-01-05    0.002015
# 1984-01-06    0.001407
# 1984-01-09   -0.000703
# 1984-01-10    0.006229
# Name: Close, dtype: float64
#
# --- n225.Close.diff() <Series> ---
# Date
# 1984-01-04     NaN
# 1984-01-05    20.0
# 1984-01-06    14.0
# 1984-01-09    -7.0
# 1984-01-10    62.0
# Name: Close, dtype: float64
#
# --- price.Close.count() <Value> ---
# 8064
#
# --- price.Close.quantile(.25) <Value> ---
# 11299.7724613
#
# --- n225.Close.quantile(.5) <Value> ---
# 16011.705078
#
# --- n225.Close.quantile(.75) <Value> ---
# 19669.0
#
# --- n225.Close.sum() <Value> ---
# 133022779.63816217
#
# --- n225.Close.cumsum() <Series> ---
# Date
# 1984-01-04     9927.0
# 1984-01-05    19874.0
# 1984-01-06    29835.0
# ...
