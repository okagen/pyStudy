# %%
# 統計用メソッドの勉強
import pandas_datareader.data as pdr
import numpy as np

start = "1949/5/6"
end = "2016/9/30"

# pandas_datareaderを使って、yahooからNIKKEI225のデータを読み込み <DataFrame>
n225 = pdr.DataReader("^N225", 'yahoo', start, end)
print('\n--- n225.Close.head(10) <Series> ---')
print(n225.Close.head(5))

# 変化率
print('\n--- price.Close.pct_change() <Series> ---')
print(price.Close.pct_change().head(5))

# 差分
print('\n--- price.Close.diff() <Series> ---')
print(price.Close.diff().head(5))

# 計数
print('\n--- price.Close.count() <Value> ---')
print(price.Close.count())

# 第１　四分位
print('\n--- price.Close.quantile(.25) <Value> ---')
print(price.Close.quantile(.25))

# 第2　四分位
print('\n--- price.Close.quantile(.5) <Value> ---')
print(price.Close.quantile(.5))

# 第3　四分位
print('\n--- price.Close.quantile(.75) <Value> ---')
print(price.Close.quantile(.75))

# 合計
print('\n--- price.Close.sum() <Value> ---')
print(price.Close.sum())

# 累積合計
print('\n--- price.Close.cumsum() <Series> ---')
print(price.Close.cumsum().head(5))

# 平均
print('\n--- price.Close.mean() <Value> ---')
print(price.Close.mean())

# 中央値
print('\n--- price.Close.median() <Value> ---')
print(price.Close.median())

# 分散(variance)
print('\n--- price.Close.var() <Value> ---')
print(price.Close.var())

# 標準偏差(standard deviation)
print('\n--- price.Close.std() <Value> ---')
print(price.Close.std())

# 歪度(skewness)
print('\n--- price.Close.skew() <Value> ---')
print(price.Close.skew())

# 尖度(kurtosis)
print('\n--- price.Close.kurt() <Value> ---')
print(price.Close.kurt())

# ボラティリティ？？？
print('\n--- volatility <Value> ---')
dp = np.log(price.Close).diff()
vol = dp.std() * np.sqrt(250)
print(vol, len(price))
# Out:
# --- n225.Close.head(10) <Series> ---
# Date
# 1984-01-04     9927.0
# 1984-01-05     9947.0
# 1984-01-06     9961.0
# 1984-01-09     9954.0
# 1984-01-10    10016.0
# Name: Close, dtype: float64
#
# --- price.Close.pct_change() <Series> ---
# Date
# 1984-01-04         NaN
# 1984-01-05    0.002015
# 1984-01-06    0.001407
# 1984-01-09   -0.000703
# 1984-01-10    0.006229
# Name: Close, dtype: float64
#
# --- price.Close.diff() <Series> ---
# Date
# 1984-01-04     NaN
# 1984-01-05    20.0
# 1984-01-06    14.0
# 1984-01-09    -7.0
# 1984-01-10    62.0
# Name: Close, dtype: float64
#
# --- price.Close.count() <Value> ---
# 8064
#
# --- price.Close.quantile(.25) <Value> ---
# 11299.7724613
#
# --- price.Close.quantile(.5) <Value> ---
# 16011.705078
#
# --- price.Close.quantile(.75) <Value> ---
# 19669.0
#
# --- price.Close.sum() <Value> ---
# 133022779.63816217
#
# --- price.Close.cumsum() <Series> ---
# Date
# 1984-01-04     9927.0
# 1984-01-05    19874.0
# 1984-01-06    29835.0
# ...
